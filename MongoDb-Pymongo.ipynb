# %%
import pymongo as pym

from pymongo import MongoClient

# %%
cluster=MongoClient("mongodb+srv://cezDbAdmin:cezDbAdmin1817@cargoez-development.b1s7z.gcp.mongodb.net/cargoez?retryWrites=true&w=majority")

# %%
airbnb_reviews = cluster["sample_airbnb"]
collection=airbnb_reviews["sample_airbnb"]

# %%
dbs = cluster.list_database_names()

# %%
for db in dbs:
    print(db)
# Out:
# admin
# cargoez
# cargoez_books
# cez_books
# config
# data_warehouse
# local
# tracking

# %%
Cezdb= cluster["cargoez"]

# %%
Cezcollec = Cezdb.list_collection_names()

# %%
for c in Cezcollec:
    print(c)
# Out:
# fcltruckerlocations
# fclrates
# seamblreports
# seahblreports
# costsheethistories
# modules
# tasks
# domesticwarehousereceipts
# global_types
# timezones
# threadgroups
# oceanports-1
# threads
# ratemargins
# checklists
# shipmenttrackings
# businesstypes
# deliveryreports
# contact_tags
# portals
# seapickuporders
# report_settings
# leads
# Copy_of_shipment_notes
# Copy_of_checklists
# costsheetmasters
# contactratings
# trackings_test
# ocean_trackings
# fmctariffrules
# checklist_settings_fields
# airratesmasters
# incomes
# Copy_of_threads
# contact_calendars
# domesticlocations
# shipments
# itemgroups
# shipment_types
# chart_of_accounts
# reports
# master_chart_of_accounts
# fmcrates
# quotenumbers
# activity_log_books
# master_tag_groups
# sequence_number_setups
# contacts
# shipment_trackings_air
# ocean_tracking_references
# bank_deposits
# shipment_events
# resources
# oceanports-old
# master_leadboards
# invoicenumbers
# boardcolumns
# system.js
# ...

# %%
cez_shipments = Cezdb["shipments"]

# %%
import pandas as pd

# %%
data = list(cez_shipments.find())

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                         _id                 companyId  \
# 0  5bf287fa83074d45a99e61e0  5bd008758adc0c324825699c
# 1  5bf2870c83074d45a99e5e55  5bd008758adc0c324825699c
# 2  5bf288cd83074d45a99e650f  5bd008758adc0c324825699c
# 3  5bf29c8983074d45a99eafc5  5bd008758adc0c324825699c
# 4  5bf2869583074d45a99e5c92  5bd008758adc0c324825699c
#
#                                              loading  \
# 0  {'loadingService': False, 'needTransloading': ...
# 1  {'loadingService': False, 'needTransloading': ...
# 2  {'loadingService': False, 'needTransloading': ...
# 3  {'loadingService': False, 'needTransloading': ...
# 4  {'loadingService': False, 'needTransloading': ...
#
#                                              packing  \
# 0  {'goodsPacked': True, 'needPackingService': Fa...
# 1  {'goodsPacked': True, 'needPackingService': Fa...
# 2  {'goodsPacked': True, 'needPackingService': Fa...
# 3  {'goodsPacked': True, 'needPackingService': Fa...
# ...

# %%
df.to_csv('data.csv', index=False)

# %%
agg=[
    {
        '$match': {
            'companyId': ObjectId('5bd008758adc0c324825699c'), 
            'createdAt': {
                '$gte': datetime(2021, 1, 1, 8, 0, 0, tzinfo=timezone.utc), 
                '$lt': datetime(2023, 1, 1, 8, 0, 0, tzinfo=timezone.utc)
            }
        }
    }, {
        '$project': {
            'service_code': '$internals.serviceCode', 
            'product': '$internals.product', 
            'lead_source': '$internals.leadSource', 
            'shipment_status': '$internals.status', 
            'Repeat customer': '$internals.repeatCustomer', 
            'Origin_country': '$routing.originCountry', 
            'Destnation_country': '$routing.destinationCountry', 
            'origin_port': '$routing.actualOriginPort', 
            'dest_port': '$routing.actualDestinationPort', 
            'move_type': '$routing.moveType', 
            'servicetype': '$routing.serviceType', 
            'Incoterm': '$routing.incoTerms', 
            'MOT': '$routing.modeOfTransport', 
            'shipmenttype': '$routing.shipmentType', 
            'natureofgoods': '$commodities.natureOfGoods', 
            'commodity_name': '$commodities.commodityName', 
            'hts': '$commodities.htsNumber', 
            'usedgoods': '$commodities.usedGoods', 
            'isvehicle': '$commodities.vehicle.active', 
            'isDG': '$commodities.hazardous.active', 
            'isHHG': '$commodities.householdGoods', 
            'chargeableUnit': '$commodities.chargeableUnit.actual', 
            'perishable': '$perishables.active', 
            'party': {
                '$arrayToObject': '$parties'
            }, 
            'fileNumber': '$fileNumber'
        }
    }, {
        '$addFields': {
            'party': '$party.billing_party.displayName'
        }
    }
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e3cc347d2ffa> in <module>
#       2     {
#       3         '$match': {
# ----> 4             'companyId': ObjectId('5bd008758adc0c324825699c'),
#       5             'createdAt': {
#       6                 '$gte': datetime(2021, 1, 1, 8, 0, 0, tzinfo=timezone.utc),
#
# NameError: name 'ObjectId' is not defined

# %%
cez_shipments.aggregate([
    {
        '$match': {
            'companyId': ObjectId('5bd008758adc0c324825699c'), 
            'createdAt': {
                '$gte': datetime(2021, 1, 1, 8, 0, 0, tzinfo=timezone.utc), 
                '$lt': datetime(2023, 1, 1, 8, 0, 0, tzinfo=timezone.utc)
            }
        }
    }, {
        '$project': {
            'service_code': '$internals.serviceCode', 
            'product': '$internals.product', 
            'lead_source': '$internals.leadSource', 
            'shipment_status': '$internals.status', 
            'Repeat customer': '$internals.repeatCustomer', 
            'Origin_country': '$routing.originCountry', 
            'Destnation_country': '$routing.destinationCountry', 
            'origin_port': '$routing.actualOriginPort', 
            'dest_port': '$routing.actualDestinationPort', 
            'move_type': '$routing.moveType', 
            'servicetype': '$routing.serviceType', 
            'Incoterm': '$routing.incoTerms', 
            'MOT': '$routing.modeOfTransport', 
            'shipmenttype': '$routing.shipmentType', 
            'natureofgoods': '$commodities.natureOfGoods', 
            'commodity_name': '$commodities.commodityName', 
            'hts': '$commodities.htsNumber', 
            'usedgoods': '$commodities.usedGoods', 
            'isvehicle': '$commodities.vehicle.active', 
            'isDG': '$commodities.hazardous.active', 
            'isHHG': '$commodities.householdGoods', 
            'chargeableUnit': '$commodities.chargeableUnit.actual', 
            'perishable': '$perishables.active', 
            'party': {
                '$arrayToObject': '$parties'
            }, 
            'fileNumber': '$fileNumber'
        }
    }, {
        '$addFields': {
            'party': '$party.billing_party.displayName'
        }
    }
])

# %%
from datetime import datetime, tzinfo, timezone
from pymongo import MongoClient
from bson import ObjectId

# %%
resu= cez_shipments.aggregate([
    {
        '$match': {
            'companyId': ObjectId('5bd008758adc0c324825699c'), 
            'createdAt': {
                '$gte': datetime(2021, 1, 1, 8, 0, 0, tzinfo=timezone.utc), 
                '$lt': datetime(2023, 1, 1, 8, 0, 0, tzinfo=timezone.utc)
            }
        }
    }, {
        '$project': {
            'service_code': '$internals.serviceCode', 
            'product': '$internals.product', 
            'lead_source': '$internals.leadSource', 
            'shipment_status': '$internals.status', 
            'Repeat customer': '$internals.repeatCustomer', 
            'Origin_country': '$routing.originCountry', 
            'Destnation_country': '$routing.destinationCountry', 
            'origin_port': '$routing.actualOriginPort', 
            'dest_port': '$routing.actualDestinationPort', 
            'move_type': '$routing.moveType', 
            'servicetype': '$routing.serviceType', 
            'Incoterm': '$routing.incoTerms', 
            'MOT': '$routing.modeOfTransport', 
            'shipmenttype': '$routing.shipmentType', 
            'natureofgoods': '$commodities.natureOfGoods', 
            'commodity_name': '$commodities.commodityName', 
            'hts': '$commodities.htsNumber', 
            'usedgoods': '$commodities.usedGoods', 
            'isvehicle': '$commodities.vehicle.active', 
            'isDG': '$commodities.hazardous.active', 
            'isHHG': '$commodities.householdGoods', 
            'chargeableUnit': '$commodities.chargeableUnit.actual', 
            'perishable': '$perishables.active', 
            'party': {
                '$arrayToObject': '$parties'
            }, 
            'fileNumber': '$fileNumber'
        }
    }, {
        '$addFields': {
            'party': '$party.billing_party.displayName'
        }
    }
])

# %%
resu

# %%
data = list(resu)

# %%
data
# Out:
# [{'_id': ObjectId('6042588b60cd2500364c58f5'),
#   'service_code': 'N',
#   'product': 'Console',
#   'lead_source': 'WofM (Word of Mouth, Referral)',
#   'shipment_status': 'Completed',
#   'Repeat customer': 'Yes',
#   'Origin_country': 'India',
#   'Destnation_country': 'United States',
#   'origin_port': 'INTUT',
#   'dest_port': 'USLAX',
#   'move_type': 'Import',
#   'servicetype': 'Port to Port',
#   'Incoterm': 'DAP - Delivered at Place',
#   'MOT': 'Sea',
#   'shipmenttype': 'FCL',
#   'natureofgoods': 'Other',
#   'commodity_name': 'CONTINUOUS BOND',
#   'hts': '1234',
#   'usedgoods': False,
#   'isvehicle': False,
#   'isDG': False,
#   'isHHG': False,
#   'chargeableUnit': 0.0,
#   'party': 'Triton Logistics And Maritime Pvt Ltd',
#   'fileNumber': 'ASST211154'},
#  {'_id': ObjectId('60426b3e60cd2500364c597d'),
#   'service_code': 'M',
#   'product': 'Console',
#   'lead_source': 'FrtNet (freightnet@air7seas.us)',
#   'shipment_status': 'Completed',
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                         _id service_code  product  \
# 0  6042588b60cd2500364c58f5            N  Console
# 1  60426b3e60cd2500364c597d            M  Console
# 2  604ba70660cd2500364c6af2            N  Console
# 3  605cba877496a90036f4aff7            X   Direct
# 4  602c197f6d01a2002cd498ad            V   Direct
#
#                        lead_source shipment_status Repeat customer  \
# 0   WofM (Word of Mouth, Referral)       Completed             Yes
# 1  FrtNet (freightnet@air7seas.us)       Completed             Yes
# 2    JCTrans (jctrans@air7seas.us)       Completed             Yes
# 3                  GglOrg (Google)       Completed             Yes
# 4      Poe (moverspoe@air7seas.us)          Active              No
#
#   Origin_country Destnation_country origin_port dest_port  ...  \
# 0          India      United States       INTUT     USLAX  ...
# 1          China      United States       CNSZX     USOAK  ...
# 2        Vietnam      United States       VNHPH     USLAX  ...
# ...
