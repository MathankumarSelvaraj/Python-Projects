# %%
from pymongo import MongoClient

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
client = MongoClient('cargoez-development-biconnector.b1s7z.gcp.mongodb.net', 27015)

# %%
mydatabase = client['cargoez_shipments']

# %%
mycollection = mydatabase.users

# %%
cursor = mycollection.find()
for record in cursor:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-11-53078b84d310> in <module>
#       1 cursor = mycollection.find()
# ----> 2 for record in cursor:
#       3     print(record)
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1205         if self.__empty:
#    1206             raise StopIteration
# -> 1207         if len(self.__data) or self._refresh():
#    1208             if self.__manipulate:
#    1209                 _db = self.__collection.database
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1098
#    1099         if not self.__session:
# -> 1100             self.__session = self.__collection.database.client._ensure_session()
#    1101
#    1102         if self.__id is None:  # Query
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
# ...

# %%
string="mongodb+srv://cezDbAdmin:cezDbAdmin1817@cargoez-development.b1s7z.gcp.mongodb.net/cargoez?retryWrites=true&w=majority"

# %%
client=MongoClient(string)

# %%
db=client['cargoez_shipements']

# %%
collection_name = client.cargoez_shipments.airtruckbols

# %%
item_details = collection_name.find()
for item in item_details:
    # This does not give a very readable output
    print(item)
# Out:
# {'_id': ObjectId('5ee395bd82c383002cc6996f'), 'pickup_from': {'address': {'_id': ObjectId('5df286dc7b08c3002c88ef5f'), 'ad_type': 'Primary', 'street': '16822, Francisquito Avenue', 'city': 'La Puente', 'state': 'California', 'country': 'United States', 'zip_code': '91744'}, 'name': 'Boxtoship LLC', 'email': 'christian.perez@boxtoship.com ', 'fax': '626-956-0779', 'phone': '+1 626 634 7656'}, 'delivery_to': {'address': {'_id': ObjectId('5d52b654f79ca300354bc091'), 'ad_type': 'Primary', 'street': '16325, South Avalon Boulevard', 'city': 'Gardena', 'state': 'California', 'country': 'United States', 'zip_code': '90248'}, 'name': 'JIT Transportation/LAX', 'email': 'aceja@jittransportation.com', 'fax': '', 'phone': '+1 562 696 1177'}, 'local_delivery': {'address': {'_id': ObjectId('5d52b654f79ca300354bc091'), 'ad_type': 'Primary', 'street': '16325, South Avalon Boulevard', 'city': 'Gardena', 'state': 'California', 'country': 'United States', 'zip_code': '90248'}, 'name': 'JIT Transportatio
# ...

# %%
item_details

# %%
print(item['pickup_from'])
# Out:
# {'name': 'Pradeepkumar Singh C/o UNIVERSAL RELOCATIONS INC', '_id': '61cca59cf0dd4500311ee70f', 'address': {'_id': ObjectId('61cca59cf0dd4500311ee71a'), 'ad_type': 'Primary', 'street': '343 NEW ROAD', 'city': 'PARSIPPANY', 'state': 'NJ', 'country': 'United States', 'zip_code': '07054'}, 'email': 'pradeep.singh@gmail.com', 'fax': '', 'phone': '+1 201 787 4088'}
